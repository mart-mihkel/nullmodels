# %%
import numpy as np
import pandas as pd

from plotnine import *
from nullmodels import *

# %%
random_noise = pd.DataFrame(np.random.uniform(0, 1, (10, 2)), columns=['precision', 'recall'])

p  = ggplot(random_noise)
p += aes('recall', 'precision')
p += geom_point()
p += geom_pr_hypergeom(200, method='tail', h0_correct=0.3)
p
